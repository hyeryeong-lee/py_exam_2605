# %%
import requests as req
from bs4 import BeautifulSoup

res = req.get('https://www.naver.com')

# print(res)

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# print(html_doc)
soup = BeautifulSoup(html_doc, 'html.parser')

alist = soup.select('a')
print(alist)
print(alist[0].text)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# Elsie

# %%
import requests as req
from bs4 import BeautifulSoup

res = req.get('https://news.naver.com/')

print(res.text)
# Out:
# <!doctype html>
# <html lang="ko">
# 	<head>
# 		<title id="browserTitleArea">네이버 뉴스</title>
#
#
#
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
#
# 		<script>
# 		var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# 		<meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi"/>
# 	<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/mnews/resources/20260518_015217/css/generated/newshome.css" />
# 			<link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" />
# <script>
# 	(function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
# </script>
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20260518_015217/js/generated/statistics_jquery.js"></script>
# 	<script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
#
#
#
# <script>
#
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cnb_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#         case "noHeight":
#
#             elImg.outerHTML = '<span class="noimage_wrap"><span class="noimage"></span></span>';
#             break;
#
#         case "displayFallback":
#             elImg.style.display = "none";
#             var elWrapper = elImg.closest("._NOIMAGE_WRAPPER");
#             if (elWrapper) {
#                 var elFallback = elWrapper.querySelector("._NOIMAGE_FALLBACK");
#                 if (elFallback) {
#                     elFallback.style.display = "block";
#                 }
#             }
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
# </script>
#
# 		<meta property="og:title"			content="네이버 뉴스"/>
#   <meta property="og:type"			content="website"/>
#   <meta property="og:url"			content="https://news.naver.com/main/home.naver"/>
#   <meta property="og:image"			content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
#   <meta property="og:description"	content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공"/>
#   <meta property="og:article:author" content="네이버">
#   <meta name="twitter:card"			content="summary">
#   <meta name="twitter:title"		content="네이버 뉴스">
#   <meta name="twitter:site"			content="네이버 뉴스">
#   <meta name="twitter:creator"		content="네이버 뉴스">
#   <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
#   <meta name="twitter:description"	content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
#
#
#         <script>
#
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox_secondary",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
# </script>
#
#
#
#
#
#
# 	</head>
#
# 	<body class=" as_mp_layout body_main">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
#
# <!-- Menu 구분  -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <section class="news_header">
#     <header class="nh_header" role="banner">
#         <div class="Ngnb">
#             <div class="Ngnb_inner">
#                 <div class="Ngnb_both">
#                     <div class="Ngnb_left">
#                         <span class="Ngnb_logo"><a href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');" class="Nlogo_link"><span class="Nicon_logo">NAVER</span></a></span>
#                         <div class="Ngnb_service">
#                             <h1 class="Nservice_item"><a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');"><span class="Nicon_service">뉴스</span></a></h1>
#                             <span class="Nservice_subitem">
#                                 <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#                                     <span class="Nicon_family Nicon_entertain">엔터</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
#                                 <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#                                     <span class="Nicon_family Nicon_sports">스포츠</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
#                                 <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#                                     <span class="Nicon_family Nicon_weather">날씨</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
#                                 <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#                                     <span class="Nicon_family Nicon_premium">프리미엄</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
#                                 <a href="https://news.naver.com/election/region2026" onclick="nclk(event,'gnb.elc2026','','');">
#                                     <span class="Nicon_family Nicon_election">지방선거</span>
#                                 </a>
#                             </span>
#                         </div>
#                     </div>
#
# <div class="Ngnb_right">
#     <div class="Ngnb_group">
#         <div id="gnb" class="gnb_dark_type2"></div>
#     </div>
#     <div class="Ngnb_my_setting">
#         <a href="https://media.naver.com/my/home" class="Ngnb_my_setting_link" onclick="nclk(event,'gnb.my','','');">
#             <span class="blind">MY</span>
#         </a>
#         <div role="tooltip" class="Ngnb_my_tooltip _MY_TOOLTIP" style="display:none">
#             <p class="Ngnb_my_tooltip_text">뉴스 이용 설정을 할 수 있어요</p>
#         </div>
#     </div>
#
#     <div class="Ngnb_search is_hidden _search_content"></div>
#     <div class="Ngnb_tool">
#         <a href="javascript:;"
#            class="Ntool_button _search_content_toggle_btn"
#            onclick="nclk(event,'gnb.sch','','');"><span class="Nicon_search">검색</span></a>
#     </div>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="Nlnb _float_lnb">
#             <div class="Nlnb_inner">
#                 <div class="Nlnb_both">
#                     <div class="Nlnb_left _lnb_scroll">
#                         <div class="Nlnb_menu Ntype_scroll">
#                             <div class="Nlnb_menu_inner _scroll">
#                                 <ul class="Nlnb_menu_list" role="menu">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item is_active"><a href="https://news.naver.com/?viewType=pc" class="Nitem_link" role="menuitem" aria-selected="true" onclick="nclk(event,'lnb.pcmedia','','');"><span class="Nitem_link_menu">언론사별</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/100" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.pol','','');"><span class="Nitem_link_menu">정치</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/101" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.eco','','');"><span class="Nitem_link_menu">경제</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/102" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.soc','','');"><span class="Nitem_link_menu">사회</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/103" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.lif','','');"><span class="Nitem_link_menu">생활/문화</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/105" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.sci','','');"><span class="Nitem_link_menu">IT/과학</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/section/104" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.wor','','');"><span class="Nitem_link_menu">세계</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item _isNew"><a href="https://news.naver.com/main/ranking/popularDay.naver" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.rank','','');"><span class="Nitem_link_menu">랭킹</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item _isNew"><a href="https://news.naver.com/newspaper/home?viewType=pc" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.paper','','');"><span class="Nitem_link_menu">신문보기</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/opinion/home" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.opi','','');"><span class="Nitem_link_menu">오피니언</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/tv/index.naver?mid=tvh" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.tv','','');"><span class="Nitem_link_menu">TV</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/factcheck/main" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.fact','','');"><span class="Nitem_link_menu">팩트체크</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://media.naver.com/algorithm" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.algo','','');"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item _isNew"><a href="https://news.naver.com/ombudsman/errorArticleList" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.correct','','');"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
#
#                                 </ul>
#                                 <div class="Nlnb_menu_my_area">
#                                     <a href="https://media.naver.com/my/home" class="Nlnb_menu_my_link" onclick="nclk(event,'gnb.my','','');">
#                                         <span class="Nlnb_menu_my_text">MY</span>
#                                     </a>
#                                     <div role="tooltip" class="Nlnb_menu_my_tooltip _MY_TOOLTIP" style="display:none">
#                                         <p class="Nlnb_menu_my_tooltip_text">뉴스 이용 설정을 할 수 있어요</p>
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </header>
# </section>
# <hr />
#
# 		<div id="ct" role="main" class="main_wrap">
#
#
#
# <div class="main_container">
#     <section class="main_content">
#         <h3 class="blind">콘텐츠</h3>
#
#
# <div class="main_sublnb">
#     <div class="main_sublnb_date">
#         <strong>05</strong>.<strong>22</strong><span>(금)</span>
#     </div>
#     <ul class="main_sublnb_menu">
#         <li class="main_sublnb_item"><a href="https://news.naver.com/main/officeList.naver " class="main_sublnb_link" onclick="nclk(event, 'slb.allmedia', '', '')">전체 언론사</a></li>
#         <li class="main_sublnb_item"><a href="https://newsstand.naver.com/" class="main_sublnb_link" target="_blank" onclick="nclk(event, 'slb.newsstand', '', '')">뉴스스탠드</a></li>
#         <li class="main_sublnb_item"><a href="https://newslibrary.naver.com/search/searchByDate.naver" class="main_sublnb_link" target="_blank" onclick="nclk(event, 'slb.library', '', '')">라이브러리</a></li>
#     </ul>
# </div>
#
#         <div class="main_brick">
#             <!-- BRICK HOUSE -->
#             <div class="grid1_wrap brick-house _brick_gid_wrapper">
#                 <div class="brick-vowel _brick_column">
#
#
#
#
#
#
#
# <div class="main_brick_item _press_main_status_wrapper">
#     <div class="comp_journal_subscribe">
#         <div class="cjs_title_wrap">
#             <h3 class="cjs_edit_title">
#                 <span class="cjs_main">언론사편집</span>
#                 <a href="#feedJournalistCard" class="cjs_subscribe_a"
#                    onclick="nclk(event, 'home.editassetting1', '', '')">
#                     <span class="subs_text">기자
#
#                     </span>
#                 </a>
#                 <a href="#feedSeriesCard" class="cjs_subscribe_a" onclick="nclk(event, 'home.editassetting2', '', '')">
#                     <span class="subs_text">연재
#
#                     </span>
#                 </a>
#             </h3>
#         </div>
#
#
#
#
#
# <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#     <div class="cjs_nf_title">
#         <span class="ico_newsflash">속보</span>
#     </div>
#     <div class="cjs_nf_list _item_list">
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/654/0000181955" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">&#034;사람 죽었다&#034; 허위신고 후 경찰에 흉기 난동…60대 현행범 체포</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">강원도민일보</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/029/0003028097" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">인권위, 내달 서울 퀴어문화축제에 인권위 부스 설치한다</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">디지털타임스</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/031/0001030535" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">&#034;구청 민원실에 여성이 흉기 들고 있다&#034;⋯경찰, 행방 추적 중</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">아이뉴스24</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/082/0001382055" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">&#034;구청 민원실에 흉기 든 여성이…&#034; 신고에 경찰 출동</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">부산일보</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/666/0000108151" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">이준석 “김수현 명예 회복되길…김세의 엄중 수사해야”</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">경기일보</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#
#                 <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/021/0002793092" onclick="nclk(event, 'home.newsflash', '', '')">
#                     <div class="cn_title_area">
#                         <h4 class="cn_title">“광주 민원실에 女가 칼들고 있다” 경찰추적</h4>
#                         <div class="cn_snippet">
#                             <div class="cn_journal_wrap">
#                                 <div class="cn_name">문화일보</div>
#                             </div>
#
#                         </div>
#                     </div>
#                 </a>
#
#
#     </div>
#     <button type="button" class="cjs_nf_btn_open is_close _toggle_btn" aria-expanded="false">
#         <span class="blind">속보 더보기</span>
#     </button>
# </div>
#
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div class="main_brick_item _channel_main_news_card_wrapper">
# 			<div class="comp_news_feed comp_news_none">
# 				<div class="cnf_journal_area">
# 					<a href="https://media.naver.com/press/656" class="cnf_journal"
# 					   onclick="nclk(event, 'home.editnfmedia', '', '')">
# 						<div class="cnf_journal_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2025/03/07/logo_656_100_20250307145652.png?type=nf36_36"
# 								 width="18" height="18" alt="" onerror="showNoImage(this)"/>
# 						</div>
# 						<em class="cnf_journal_name">대전일보</em>
# 						<span class="cnf_journal_sub">05월 22일 14:53</span>
# 					</a>
# 					<button type="button" class="cnf_btn_subscription _subscribe_btn"
# 							data-office_id="656"
# 							data-office_name="대전일보"
# 							onclick="nclk(event, 'home.editnfset', '', '')"><span class="blind">구독</span></button>
# 				</div>
# 				<a href="https://n.news.naver.com/article/656/0000177029" class="cnf_news_area _cds_link _editn_link"
# 				   onclick="nclk(event, 'home.editnfimg', '', '')">
#
# 						<div class="cnf_news_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/origin/656/2026/05/22/177029.jpg?type=nf168_108&ut=20260522105008"
# 								 width="80" height="54" alt="" onerror="showNoImage(this)">
#
# 						</div>
#
# 					<strong class="cnf_news_title">국민참여성장펀드 오늘부터 선착순 판매…5년간 환매 불가</strong>
# 				</a>
# 				<ul class="cnf_news_list">
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/656/0000177040" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">檢, &#039;신생아 매매&#039; 혐의 미혼모·부부에 징역 2-6년 구형</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/656/0000177008" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">[뉴스 즉설]딱 붙은 박수현-김태흠, 점점 험해지는 신용한-김영환</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/656/0000177045" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">보이스피싱에 속아 &#039;셀프감금&#039; 20대…수천만원 피해 직전 구조</a>
# 						</li>
#
# 				</ul>
# 			</div>
#
# 		</div>
#
#
#
# 		<div class="main_brick_item _channel_main_news_card_wrapper">
# 			<div class="comp_news_feed comp_news_none">
# 				<div class="cnf_journal_area">
# 					<a href="https://media.naver.com/press/607" class="cnf_journal"
# 					   onclick="nclk(event, 'home.editnfmedia', '', '')">
# 						<div class="cnf_journal_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/upload/office_logo/607/2025/03/07/logo_607_100_20250307145627.png?type=nf36_36"
# 								 width="18" height="18" alt="" onerror="showNoImage(this)"/>
# 						</div>
# 						<em class="cnf_journal_name">뉴스타파</em>
# 						<span class="cnf_journal_sub">05월 21일 18:00</span>
# 					</a>
# 					<button type="button" class="cnf_btn_subscription _subscribe_btn"
# 							data-office_id="607"
# 							data-office_name="뉴스타파"
# 							onclick="nclk(event, 'home.editnfset', '', '')"><span class="blind">구독</span></button>
# 				</div>
# 				<a href="https://n.news.naver.com/article/607/0000003332" class="cnf_news_area _cds_link _editn_link"
# 				   onclick="nclk(event, 'home.editnfimg', '', '')">
#
# 						<div class="cnf_news_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/origin/607/2026/05/21/3332.jpg?type=nf168_108&ut=20260521180014"
# 								 width="80" height="54" alt="" onerror="showNoImage(this)">
#
# 						</div>
#
# 					<strong class="cnf_news_title">[주간 뉴스타파] 내란을 내란이라고 말 못하는 후보들</strong>
# 				</a>
# 				<ul class="cnf_news_list">
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/607/0000003331" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">내란 옹호, 탄핵 반대 후보 추적 ③ 충남, 서산</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/607/0000003330" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">내란 옹호, 탄핵 반대 후보 추적 ② 창원, 김해</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/607/0000003329" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">내란 옹호, 탄핵 반대 후보 추적 ① 부산, 울산</a>
# 						</li>
#
# 				</ul>
# 			</div>
#
# 		</div>
#
#
#
# 		<div class="main_brick_item _channel_main_news_card_wrapper">
# 			<div class="comp_news_feed comp_news_none">
# 				<div class="cnf_journal_area">
# 					<a href="https://media.naver.com/press/215" class="cnf_journal"
# 					   onclick="nclk(event, 'home.editnfmedia', '', '')">
# 						<div class="cnf_journal_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2025/03/07/logo_215_100_20250307145651.png?type=nf36_36"
# 								 width="18" height="18" alt="" onerror="showNoImage(this)"/>
# 						</div>
# 						<em class="cnf_journal_name">한국경제TV</em>
# 						<span class="cnf_journal_sub">05월 22일 14:35</span>
# 					</a>
# 					<button type="button" class="cnf_btn_subscription _subscribe_btn"
# 							data-office_id="215"
# 							data-office_name="한국경제TV"
# 							onclick="nclk(event, 'home.editnfset', '', '')"><span class="blind">구독</span></button>
# 				</div>
# 				<a href="https://n.news.naver.com/article/215/0001253011" class="cnf_news_area _cds_link _editn_link"
# 				   onclick="nclk(event, 'home.editnfimg', '', '')">
#
# 						<div class="cnf_news_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/origin/215/2026/05/22/1253011.jpg?type=nf168_108&ut=20260522104506"
# 								 width="80" height="54" alt="" onerror="showNoImage(this)">
#
# 						</div>
#
# 					<strong class="cnf_news_title">&#034;투자손실 20%까진 나라가 보전&#034;…개미들 가입 &#039;쇄도&#039;</strong>
# 				</a>
# 				<ul class="cnf_news_list">
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/215/0001252970" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">&#034;스페이스X 주식, 토큰으로 산다&#034;…삼성전자·하이닉스는 언제</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/215/0001253025" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">불매운동이 &#039;저가 매수&#039; 기회?…&#039;스타벅스&#039; 검색 76% 늘어난 곳</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/215/0001253022" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">펄펄 끓는 바다…올여름 &#039;찜통더위·물폭탄&#039; 온다</a>
# 						</li>
#
# 				</ul>
# 			</div>
#
# 		</div>
#
#
#
# 		<div class="main_brick_item _channel_main_news_card_wrapper">
# 			<div class="comp_news_feed comp_news_none">
# 				<div class="cnf_journal_area">
# 					<a href="https://media.naver.com/press/661" class="cnf_journal"
# 					   onclick="nclk(event, 'home.editnfmedia', '', '')">
# 						<div class="cnf_journal_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2025/03/07/logo_661_100_20250307145705.png?type=nf36_36"
# 								 width="18" height="18" alt="" onerror="showNoImage(this)"/>
# 						</div>
# 						<em class="cnf_journal_name">JIBS</em>
# 						<span class="cnf_journal_sub">05월 22일 14:00</span>
# 					</a>
# 					<button type="button" class="cnf_btn_subscription _subscribe_btn"
# 							data-office_id="661"
# 							data-office_name="JIBS"
# 							onclick="nclk(event, 'home.editnfset', '', '')"><span class="blind">구독</span></button>
# 				</div>
# 				<a href="https://n.news.naver.com/article/661/0000076749" class="cnf_news_area _cds_link _editn_link"
# 				   onclick="nclk(event, 'home.editnfimg', '', '')">
#
# 						<div class="cnf_news_thumb">
# 							<img loading='lazy'
# 								 data-src="https://mimgnews.pstatic.net/image/origin/661/2026/05/22/76749.jpg?type=nf168_108&ut=20260522110609"
# 								 width="80" height="54" alt="" onerror="showNoImage(this)">
#
# 						</div>
#
# 					<strong class="cnf_news_title">홍준표 &#034;5.18과 4.3, 두 번 다시 일어나선 안될 참상.. 최근 사태 참으로 유감&#034;</strong>
# 				</a>
# 				<ul class="cnf_news_list">
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/661/0000076746" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">“거기 커피 아니죠?”… 익선동 골목서 나온 李 한마디, 스타벅스 다시  불붙었다</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/661/0000076750" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">“편수 늘어봐야 좌석이 줄어”… 17만 ‘제주행’ 석탄일 연휴, 흐름이 달라졌다</a>
# 						</li>
#
# 						<li class="cnf_news_item">
# 							<a href="https://n.news.naver.com/article/661/0000076751" class="cnf_news _cds_link _editn_link"
# 							   onclick="nclk(event, 'home.editnfimg', '', '')">귀가하던 여중생 폭행하며 납치하려 한 60대 구속.. 누범 기간  범행</a>
# 						</li>
# ...
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.title = "구독 및 추천 채널";
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
# </script>
#         </div>
#     </section>
#
#     <div class="layer_toast" style="display: none"></div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#         <button type="button" class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')"></button>
#     </div>
# </div>
#
# 		</div>
#
# </div>
#
# <!-- //ct -->
#
#
#
#
#
#
# <hr />
# <div class="mp_footer">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="f_subinfo">
#         <div class="f_subinfoinner">
#             <div class="f_notice">
#                 <h5 class="f_notice_badge">공지</h5>
#                 <a href="https://news.naver.com/ombudsman/news/31390"
#                    data-mpurl='{"m":"https://news.naver.com/ombudsman/news/31390","p":"https://news.naver.com/ombudsman/news/31390"}'
#                    class="f_notice_link" onclick="nclk(event, 'fot.noticetext', '', '');">
#                     <p class="f_notice_text">제9회 지방선거 특집페이지 출시 안내</p>
#                 </a>
#             </div>
#         </div>
#     </div>
#
#
#     <div class="f_maininfo">
#         <div class="f_maininfoinner">
#             <a href="javascript:topPage();" class="r_pg_top _go_top" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">맨위로</a>
#
#             <footer role="contentinfo">
#                 <p class="u_cr">
#
#
#
#
#
# <span class="u_ftm _footer_login">
#     <span class="u_cri u_cri_v1"><a href="https://m.naver.com/services.html"  data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' class="u_cra" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a></span>
# </span>
# <span class="u_ftm">
#     <span class="u_cri u_cri_v1"><a href="https://news.naver.com/ombudsman" data-mpurl='{"m":"https://news.naver.com/ombudsman","p":"https://news.naver.com/ombudsman"}' class="u_cra" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
#     <span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_001.naver" data-mpurl='{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}' class="u_cra" onclick="nclk(event,'fot.report','','');">오류신고</a></span>
#     <span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_007.naver" data-mpurl='{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}' class="u_cra" onclick="nclk(event,'fot.help','','');">고객센터</a></span>
# </span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <span class="cr_rule">
#
#     <span class="cr_rulea">청소년 보호 책임자 : 이정규</span>
# </span>
#
# <span class="u_presscopy">
#     각 언론사가 직접 콘텐츠를 편집합니다.
#
# </span>
#
# <span class="u_copyright">이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</span>
# <span class="u_naverlogo"><a href="https://www.navercorp.com/" data-mpurl='{"m":"https://www.navercorp.com/","p":"https://www.navercorp.com/"}' class="u_naverlogo_a" id="nhnLink" onclick="nclk(event,'fot.navercorp','','');">NAVER</a></span>
#
#                 </p>
#             </footer>
#         </div>
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
# 				<script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20260518_015217/js/generated/news.mobile.js"></script>
#
# 				<script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20260518_015217/js/generated/pressmain.dependency.js"></script>
#
#
#
#
#
# 		<script type="text/javascript">
#     var config = {
#         "neloCollectorUrl": "https://kr-col-ext.nelo.navercorp.com/_store",
#         "projectName": "P638fcb_news-mobile-front",
#         "host": "real"
#     }
#
#     try{
#         neloSender.init(config);
#     }catch(e){}
# </script>
#
#
# 		<script type="text/javascript">
# /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         var isMyTooltipClosed = cookie.getItem("MY_TOOLTIP_CLOSED");
#         if(isMyTooltipClosed == null) {
#             var $myTooltips = $("._MY_TOOLTIP");
#             if($myTooltips.length > 0) {
#                 cookie.setItem("MY_TOOLTIP_CLOSED", "1", 1, "news.naver.com", "/");
#                 $myTooltips.show();
#                 setTimeout(function() {
#                     $myTooltips.hide();
#                 }, 5000);
#             }
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_cra" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a></span>')
#             }else {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="'+loginUrl+'" class="u_cra" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a></span>')
#             }
#         }
#     }
# });
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#     {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
# </script>
# <script type="text/javascript">
#     try {
#         FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#         FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#         FeedAccordionIssueCard($('._issue_feed_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] FeedCard 스크립트 오류 " + e);
#     }
#
#     try {
#         BrickGridForEditByPress($("._brick_gid_wrapper"));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] BrickGridForEditByPress 스크립트 오류 " + e);
#     }
#
#     try {
#         PressMainStatusCard($('._press_main_status_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] PressMainStatusCard 스크립트 오류 " + e);
#     }
#
#     try {
#         NewsFlashCard($('._newsflash_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] NewsFlashCard 스크립트 오류 " + e);
#     }
#
#     try {
#
#
#         window.gladsdk.cmd.push(function () {
#             var adSlots = [];
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox"));
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox_secondary"));
#
#             var adDedupManager = window.gladsdk.setAdDeduplication("pressmain_ad");
#             if (isBackForwardNavigated()) {
#                 adDedupManager.restoreAds(adSlots);
#             } else {
#                 adDedupManager.displayAds(adSlots);
#             }
#
#
#             window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").hide();
#             });
#
#             window.gladsdk.addEventListener(window.gladsdk.event.AD_LOADED, function (ad) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").show();
#             });
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] 광고 호출 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._channel_news_card_wrapper').each(function () {
#             var wrapper = $(this);
#             ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelNewsCard 스크립트 오류" + e);
#     }
#
#     try {
#         ChannelMainNewsCard($('._channel_main_news_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelMainNewsCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#         SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SubscribeBannerCard 스크립트 오류 " + e);
#     }
#
#     try {
#         WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] WeeklySpecialReportCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._tab_card_wrapper').each(function () {
#             var wrapper = $(this);
#             TabCard(wrapper);
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] TabCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._horizontal_card_wrapper').each(function () {
#             var wrapper = $(this);
#             HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] HorizontalTypeCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SpecialReportCard 스크립트 오류 " + e);
#     }
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#     // Impression
#     try {
#         news.Impression.getInstance().init();
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] Impression init 스크립트 오류 " + e);
#     }
#
#     new news.ImageLazyLoader().load("img[data-src]");
# </script>
#
#
#
# 		<script>
#     var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2026052215";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
# </script>
#
# <script>
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
# </script>
# <script>
# doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
# </script>
# 		<!-- LCS -->
#
#
#
#
# <script type="text/javascript">
#
# function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
# </script>
#
#
#
#
#
#
# <script type="text/javascript">
#     window.ntm_news = window.ntm_news || [];
#
#     doAfterLoadEnd(function () {
#         var ntmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
#
#
#
#
#         ntmInit(ntmUrl);
#     });
# </script>
#
#
# <script type="text/javascript">
#     // NLog pageview 전송
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jQuery(window).on(eventType, function() {
#         var sti = "";
#         var gdid = "";
#
#
#
#
#
#
#                 if (isMobileDevice()) {
#                     // mobile
#
#                         sti = "m_news";
#
#                 } else {
#                     // pc
#
#                 }
#
#
#
#         // ma 전송
#         try {
#             initMa();
#         } catch (e) {
#         }
#
#         ntmCustomPageViewSend({
#             sti: sti,
#             gdid: gdid
#         });
#     });
# </script>
#
# 		<!-- //LCS -->
# 		<div id="videoWrap"></div>
# 	</body>
# </html>
